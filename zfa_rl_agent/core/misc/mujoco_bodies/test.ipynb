# %%
from dm_control import suite
from dm_control import mjcf
from dm_control import viewer
# Out:
# /home/rdkeller/miniconda3/envs/fishies/lib/python3.12/site-packages/glfw/__init__.py:914: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)

# %%
path = '/home/rdkeller/zebrafish_agent/mujoco_bodies/swimmer5.xml'
mjcf_model = mjcf.from_path(path)
print(mjcf_model)
# Out:
# <mujoco model="swimmer">...</mujoco>

# %%
# Out:
# /home/rdkeller/miniconda3/envs/fishies/lib/python3.12/site-packages/glfw/__init__.py:914: GLFWError: (65537) b'The GLFW library is not initialized'
#   warnings.warn(message, GLFWError)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 viewer.launch(mjcf_model)
#
# File ~/miniconda3/envs/fishies/lib/python3.12/site-packages/dm_control/viewer/__init__.py:39, in launch(environment_loader, policy, title, width, height)
#      22 def launch(environment_loader, policy=None, title='Explorer', width=1024,
#      23            height=768):
#      24   """Launches an environment viewer.
#      25
#      26   Args:
#    (...)
#      37       ValueError: When 'environment_loader' argument is set to None.
#      38   """
# ---> 39   app = application.Application(title=title, width=width, height=height)
# ...
