# %%
import numpy as np
import os
import xarray
import pickle
import sys
from os.path import dirname, join, abspath
sys.path.insert(0, abspath(join(dirname("default_dirs.py"), '..')))

from zfa.core.default_dirs import DATA_ROOT, BASE_DIR

# %%
BASE_DIR
# Out:
# '/om2/group/yanglab/zfa/'

# %%
# check that I can load the stored data back
with open("/data/user_data/rdkeller/zfa/" + "job_info_for_chunking.pickle", "rb") as handle:
    info = pickle.load(handle)

# %%
info.keys()
# Out:
# dict_keys(['sub-20170228-3_ses-20170228T165730_ophys', 'sub-20170228-4_ses-20170228T185002_ophys'])

# %%
info['sub-20170228-3_ses-20170228T165730_ophys']
# Out:
# {'glial_num_units': 126467,
#  'neural_num_units': 111378,
#  'glial_units': [(0, 5000),
#   (5000, 10000),
#   (10000, 15000),
#   (15000, 20000),
#   (20000, 25000),
#   (25000, 30000),
#   (30000, 35000),
#   (35000, 40000),
#   (40000, 45000),
#   (45000, 50000),
#   (50000, 55000),
#   (55000, 60000),
#   (60000, 65000),
#   (65000, 70000),
#   (70000, 75000),
#   (75000, 80000),
#   (80000, 85000),
#   (85000, 90000),
#   (90000, 95000),
#   (95000, 100000),
#   (100000, 105000),
#   (105000, 110000),
#   (110000, 115000),
#   (115000, 120000),
#   (120000, 125000),
#   (125000, 126467)],
#  'neural_units': [(0, 5000),
#   (5000, 10000),
#   (10000, 15000),
#   (15000, 20000),
#   (20000, 25000),
#   (25000, 30000),
#   (30000, 35000),
#   (35000, 40000),
#   (40000, 45000),
#   (45000, 50000),
#   (50000, 55000),
#   (55000, 60000),
#   (60000, 65000),
#   (65000, 70000),
#   (70000, 75000),
#   (75000, 80000),
#   (80000, 85000),
#   (85000, 90000),
#   (90000, 95000),
# ...
